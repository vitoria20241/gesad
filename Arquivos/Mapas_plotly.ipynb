# %% [markdown]
# # Santa Catarina

# %%
import pandas as pd
import plotly.express as px
from dash import Dash, dcc
import plotly.offline as pyo

# %%
tab = pd.read_csv('C:\\GESAD\\Inputs\\tabela6805_SC.csv') # Dados IBGE 2022 
tab.head()
# Out:
#        Cód      Município  Total  \
# 0  4200051  Abdon Batista    100
# 1  4200101   Abelardo Luz    100
# 2  4200200     Agrolândia    100
# 3  4200309     Agronômica    100
# 4  4200408      Água Doce    100
#
#   Rede geral, rede pluvial ou fossa ligada à rede Rede geral ou pluvial  \
# 0                                            32.2                 31.06
# 1                                            2.34                  1.91
# 2                                           53.42                 14.61
# 3                                           40.87                  7.27
# 4                                           21.48                  10.7
#
#   Fossa séptica ou fossa filtro ligada à rede  \
# 0                                        1.14
# 1                                        0.43
# 2                                       38.81
# 3                                        33.6
# 4                                       10.78
#
#   Fossa séptica ou fossa filtro não ligada à rede  Fossa rudimentar ou buraco  \
# 0                                           34.26                       32.61
# 1                                           18.54                       78.44
# 2                                           41.49                        3.83
# 3                                              45                       12.25
# 4                                            55.6                       22.55
#
#    Vala Rio, lago, córrego ou mar Outra forma  \
# 0  0.31                         -        0.31
# 1  0.41                      0.22        0.03
# 2  0.77                      0.43        0.05
# 3  1.12                      0.76           -
# 4  0.12                      0.16        0.08
#
#   Não tinham banheiro nem sanitário
# 0                              0.31
# 1                              0.02
# 2                                 -
# 3                                 -
# 4                                 -

# %%
tab.replace('-', 0, inplace=True)
tab
# Out:
#          Cód         Município  Total  \
# 0    4200051     Abdon Batista    100
# 1    4200101      Abelardo Luz    100
# 2    4200200        Agrolândia    100
# 3    4200309        Agronômica    100
# 4    4200408         Água Doce    100
# ..       ...               ...    ...
# 290  4219507           Xanxerê    100
# 291  4219606         Xavantina    100
# 292  4219705             Xaxim    100
# 293  4219853            Zortéa    100
# 294  4220000  Balneário Rincão    100
#
#     Rede geral, rede pluvial ou fossa ligada à rede Rede geral ou pluvial  \
# 0                                              32.2                 31.06
# 1                                              2.34                  1.91
# 2                                             53.42                 14.61
# 3                                             40.87                  7.27
# 4                                             21.48                  10.7
# ..                                              ...                   ...
# 290                                           12.32                  8.52
# 291                                           23.94                     2
# 292                                            7.44                   4.1
# 293                                            0.68                  0.48
# 294                                             4.3                  2.39
#
#     Fossa séptica ou fossa filtro ligada à rede  \
# 0                                          1.14
# 1                                          0.43
# 2                                         38.81
# 3                                          33.6
# 4                                         10.78
# ..                                          ...
# 290                                        3.79
# 291                                       21.95
# 292                                        3.34
# 293                                        0.21
# 294                                        1.91
#
#     Fossa séptica ou fossa filtro não ligada à rede  \
# 0                                             34.26
# 1                                             18.54
# 2                                             41.49
# 3                                                45
# 4                                              55.6
# ..                                              ...
# 290                                           57.63
# 291                                           55.63
# 292                                           64.49
# 293                                           93.37
# 294                                            53.5
#
#      Fossa rudimentar ou buraco  Vala Rio, lago, córrego ou mar Outra forma  \
# 0                         32.61  0.31                         0        0.31
# 1                         78.44  0.41                      0.22        0.03
# 2                          3.83  0.77                      0.43        0.05
# 3                         12.25  1.12                      0.76           0
# 4                         22.55  0.12                      0.16        0.08
# ..                          ...   ...                       ...         ...
# 290                       28.55   0.3                      1.11        0.08
# 291                       19.79   0.4                         0        0.24
# 292                       27.58  0.06                      0.36        0.07
# 293                        5.67  0.14                      0.14           0
# 294                       42.12  0.03                      0.02        0.03
#
#     Não tinham banheiro nem sanitário
# 0                                0.31
# 1                                0.02
# 2                                   0
# 3                                   0
# 4                                   0
# ..                                ...
# 290                                 0
# 291                                 0
# 292                                 0
# 293                                 0
# 294                                 0
#
# [295 rows x 12 columns]

# %%
# String para float
aux = tab.columns.tolist() 
aux.pop(1)

for i in range(len(aux)):
    if aux[i] in tab.columns.tolist():
        tab[aux[i]] = tab[aux[i]].astype(float)

# %%
# GeoJSON
geojson_url = 'https://raw.githubusercontent.com/tbrugz/geodata-br/master/geojson/geojs-42-mun.json'

# %%
# Mapa
fig = px.choropleth_mapbox(
    data_frame = tab,
    geojson = geojson_url,
    locations = 'Município',
    featureidkey = 'properties.name',
    color = 'Rede geral, rede pluvial ou fossa ligada à rede',
    color_continuous_scale = 'sunsetdark',
    range_color = (tab['Rede geral, rede pluvial ou fossa ligada à rede'].min(), tab['Rede geral, rede pluvial ou fossa ligada à rede'].max()),
    mapbox_style = 'open-street-map',
    zoom = 6.5,
    center = {"lat": -27.5, "lon": -51.25},
    opacity = 1,
    width = 1200,
    height = 800,
    labels = {'Rede geral, rede pluvial ou fossa ligada à rede': 'Rede geral, rede pluvial ou fossa ligada à rede (%)'},
    hover_name = 'Município', 
    hover_data = {'Município': False}
)


# layout
fig.update_layout(
    margin={'r': 0, 't': 1, 'l': 0, 'b': 1},
    coloraxis_colorbar={
        'title': {
            'text': 'Domicílios particulares permanentes ocupados (%)',
            'side': 'right'
        }
    }
)

fig.update_geos(
    showcoastlines=False,  
    visible=False  
)

fig.update_traces(
    marker_line_width=0.05,
    selector=dict(type='choroplethmapbox')
)

fig.show()

# %%
pyo.offline.plot(fig, filename = 'mapaSC.html') # criando o arquivo html
# Out:
# 'mapaSC.html'

# %% [markdown]
# https://vitoria20241.github.io/mapaSC/
